# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import clone_model
from tensorflow.keras.applications import EfficientNetV2B0
from sklearn.metrics import log_loss, accuracy_score, classification_report
from transformers import AutoModel, TFAutoModel, AutoTokenizer, BertTokenizer
# Out:
# 2025-05-19 10:02:53.546419: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dataVal = tf.data.Dataset.load(
    "dataVal",
    element_spec=({
        'title': tf.TensorSpec(shape=(None, 32), dtype=tf.int32),
        'content': tf.TensorSpec(shape=(None, 128), dtype=tf.int32),
        'titlemask': tf.TensorSpec(shape=(None, 32), dtype=tf.int32),
        'contentmask': tf.TensorSpec(shape=(None, 128), dtype=tf.int32),
        'image': tf.TensorSpec(shape=(None, 384, 384, 3), dtype=tf.uint8)
    }, tf.TensorSpec(shape=(None, 2), dtype=tf.float64))
)
dataVal
# Out:
# 2025-05-19 10:02:55.877726: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:55.881802: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:55.881839: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:55.884211: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:55.884246: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:55.884268: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:56.052811: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:56.052859: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:56.052867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-05-19 10:02:56.052898: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:05:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-19 10:02:56.052919: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5564 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:05:00.0, compute capability: 8.6
# <_LoadDataset element_spec=({'title': TensorSpec(shape=(None, 32), dtype=tf.int32, name=None), 'content': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None), 'titlemask': TensorSpec(shape=(None, 32), dtype=tf.int32, name=None), 'contentmask': TensorSpec(shape=(None, 128), dtype=tf.int32, name=None), 'image': TensorSpec(shape=(None, 384, 384, 3), dtype=tf.uint8, name=None)}, TensorSpec(shape=(None, 2), dtype=tf.float64, name=None))>

# %%
model.load_model("models/")
model.evaluate(dataVal)
# Out:
# /home/sadrian/miniconda3/envs/tf216/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 520 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2025-05-19 10:03:18.568655: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 30s 263ms/step - binary_accuracy: 0.4359 - loss: 6.6713
# [6.756562232971191, 0.426364928483963]
